# %%
# %gui wx
import sys
import os

#####################
# Import of utils.py functions
#####################
# Required to get utils.py and access its functions
notebook_dir = os.path.abspath("")
parent_dir = os.path.abspath(os.path.join(notebook_dir, '..'))
sys.path.append(parent_dir)
sys.path.append('.')
from utils import loadFSL, FSLeyesServer, mkdir_no_exist, interactive_MCQ,get_json_from_file

####################
# DIPY_HOME should be set prior to import of dipy to make sure all downloads point to the right folder
####################
os.environ["DIPY_HOME"] = "/home/jovyan/Data"


#############################
# Loading fsl and freesurfer within Neurodesk
# You can find the list of available other modules by clicking on the "Softwares" tab on the left
#############################
import lmod
await lmod.purge(force=True)
await lmod.load('fsl/6.0.7.4')
await lmod.load('freesurfer/7.4.1')
await lmod.list()

####################
# Setup FSL path
####################
loadFSL()

###################
# Load all relevant libraries for the lab
##################
import fsl.wrappers
from fsl.wrappers import fslmaths

import mne_nirs
import nilearn
from nilearn.datasets import fetch_development_fmri

import mne
import mne_nirs
import dipy
from dipy.data import fetch_bundles_2_subjects, read_bundles_2_subjects
import xml.etree.ElementTree as ET
import os.path as op
import nibabel as nib
import glob

import ants
import openneuro
from mne.datasets import sample
from mne_bids import BIDSPath, read_raw_bids, print_dir_tree, make_report


# Useful imports to define the direct download function below
import requests
import urllib.request
from tqdm import tqdm


# FSL function wrappers which we will call from python directly
from fsl.wrappers import fast, bet
from fsl.wrappers.misc import fslroi
from fsl.wrappers import flirt

# General purpose imports to handle paths, files etc
import glob
import pandas as pd
import numpy as np
import json

from IPython.display import display, HTML

# %%
################
# Start FSLeyes (very neat tool to visualize MRI data of all sorts) within Python
################
fsleyesDisplay = FSLeyesServer()
fsleyesDisplay.show()
# Out:
# 12:13:53: Debug: Adding duplicate image handler for 'Windows bitmap file'
# 12:13:53: Debug: Adding duplicate animation handler for '1' type
# 12:13:53: Debug: Adding duplicate animation handler for '2' type
# 12:13:53: Debug: Adding duplicate image handler for 'Windows bitmap file'
# 12:13:53: Debug: Adding duplicate animation handler for '1' type
# 12:13:53: Debug: Adding duplicate animation handler for '2' type
#
# (ipykernel_launcher.py:4575): Gtk-CRITICAL **: 12:13:54.465: gtk_window_resize: assertion 'height > 0' failed

# %%
import subprocess

dataset_id = 'ds000171'
subject = '01'

sample_path = "/home/jovyan/Mini_Project_1/dataset"
mkdir_no_exist(sample_path)
bids_root = op.join(os.path.abspath(""),sample_path, dataset_id)
deriv_root = op.join(bids_root, 'derivatives')
preproc_root = op.join(bids_root, 'derivatives','preprocessed_data')

fmap_path = op.join(bids_root, 'sub-control01', 'func')
subject_dir = 'sub-control{}'.format(subject)

##################
# Solution
# There are two solutions
# The easiest is simply to include all data of subject-01
# The other is to add one line for the fieldmaps
##################
# Change the command below to include files in the fmap subdirectory
# You should STILL be loading the EPI and anatomical

# Simple variant to include everything from subject-01
subprocess.run(["openneuro-py", "download", "--dataset", dataset_id, # Openneuro has for each dataset a unique identifier
                "--target-dir", bids_root,  # The path where we want to save our data. You should save your data under /home/jovyan/Data/[your dataset ID] to be 100% fool-proof
                "--include", subject_dir # Effectively get all data
               ], check=True)
# Out:
# 👋 Hello! This is openneuro-py 2024.2.0. Great to see you! 🤗
#
#    👉 Please report problems 🤯 and bugs 🪲 at
#       https://github.com/hoechenberger/openneuro-py/issues
#
# 🌍 Preparing to download ds000171 …
# 📁 Traversing directories for ds000171 : 18 entities [00:09,  1.99 entities/s]
# 📥 Retrieving up to 15 files (5 concurrent downloads).
# sub-control01_T1w.nii.gz:   1%|          | 48.5k/8.77M [00:00<00:33, 271kB/s]
# sub-control01_task-music_run-2_events.tsv:   0%|          | 0.00/339 [00:00<?, ?B/s]
#
# sub-control01_task-music_run-1_bold.nii.gz:   0%|          | 0.00/33.8M [00:00<?, ?B/s]
#
# sub-control01_T1w.nii.gz:   1%|          | 99.5k/8.77M [00:00<00:32, 279kB/s]0<?, ?B/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   0%|          | 0.00/33.9M [00:00<?, ?B/s]
# sub-control01_task-music_run-1_bold.nii.gz:   0%|          | 66.5k/33.8M [00:00<01:34, 373kB/s]
#
# sub-control01_T1w.nii.gz:   2%|▏         | 167k/8.77M [00:00<00:27, 325kB/s] 00<01:13, 483kB/s]
#
#
#
# sub-control01_task-music_run-3_events.tsv:   0%|          | 0.00/339 [00:00<?, ?B/s]
#
#
#
#
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   0%|          | 49.5k/33.9M [00:00<02:11, 269kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   0%|          | 117k/33.8M [00:00<01:49, 322kB/s]
#
# sub-control01_T1w.nii.gz:   3%|▎         | 235k/8.77M [00:00<00:25, 346kB/s]00<00:40, 875kB/s]
#
# sub-control01_task-music_run-3_bold.nii.gz:   2%|▏         | 748k/33.9M [00:00<00:16, 2.08MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   1%|          | 185k/33.8M [00:00<01:41, 348kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   0%|          | 83.5k/33.9M [00:00<03:19, 178kB/s]
#
# sub-control01_T1w.nii.gz:   3%|▎         | 303k/8.77M [00:00<00:24, 358kB/s]:00<00:08, 3.87MB/s]
#
#
#
# sub-control01_task-nonmusic_run-4_bold.nii.gz:   0%|          | 0.00/33.9M [00:00<?, ?B/s]
#
# sub-control01_task-music_run-3_bold.nii.gz:   8%|▊         | 2.77M/33.9M [00:00<00:04, 6.85MB/s]
# sub-control01_T1w.nii.gz:   4%|▍         | 371k/8.77M [00:01<00:24, 365kB/s]00<01:28, 399kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   0%|          | 117k/33.9M [00:00<03:52, 152kB/s]
#
#
#
# sub-control01_task-nonmusic_run-4_bold.nii.gz:   0%|          | 85.5k/33.9M [00:00<01:12, 485kB/s]
#
# sub-control01_task-music_run-3_bold.nii.gz:  16%|█▌        | 5.30M/33.9M [00:00<00:02, 10.9MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   1%|          | 338k/33.8M [00:00<01:29, 393kB/s]
#
#
#
# sub-control01_task-nonmusic_run-4_bold.nii.gz:   1%|          | 221k/33.9M [00:00<00:40, 877kB/s]
#
# sub-control01_T1w.nii.gz:   5%|▌         | 456k/8.77M [00:01<00:21, 401kB/s]:00<00:01, 15.3MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   0%|          | 151k/33.9M [00:00<03:35, 164kB/s]
#
# sub-control01_task-music_run-3_bold.nii.gz:  32%|███▏      | 11.0M/33.9M [00:01<00:01, 19.9MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   1%|          | 423k/33.8M [00:01<01:23, 421kB/s]
#
#
#
# sub-control01_task-nonmusic_run-4_bold.nii.gz:   2%|▏         | 612k/33.9M [00:00<00:21, 1.64MB/s]
#
# sub-control01_T1w.nii.gz:   6%|▌         | 524k/8.77M [00:01<00:21, 394kB/s]:01<00:01, 20.8MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   1%|          | 185k/33.9M [00:01<03:26, 171kB/s]
#
#
#
# sub-control01_task-nonmusic_run-4_bold.nii.gz:   4%|▎         | 1.25M/33.9M [00:00<00:10, 3.19MB/s]
#
# sub-control01_task-music_run-3_bold.nii.gz:  49%|████▊     | 16.5M/33.9M [00:01<00:00, 24.8MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   1%|▏         | 508k/33.8M [00:01<01:19, 439kB/s]
#
#
#
# sub-control01_task-nonmusic_run-4_bold.nii.gz:   8%|▊         | 2.75M/33.9M [00:00<00:04, 6.96MB/s]
#
# sub-control01_T1w.nii.gz:   7%|▋         | 609k/8.77M [00:01<00:20, 418kB/s]:01<00:00, 25.4MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   1%|          | 219k/33.9M [00:01<03:19, 177kB/s]
#
#
#
# sub-control01_task-nonmusic_run-4_bold.nii.gz:  12%|█▏        | 4.23M/33.9M [00:00<00:03, 9.55MB/s]
#
# sub-control01_task-music_run-3_bold.nii.gz:  66%|██████▌   | 22.4M/33.9M [00:01<00:00, 28.2MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   2%|▏         | 593k/33.8M [00:01<01:17, 450kB/s]
#
#
#
# sub-control01_T1w.nii.gz:   8%|▊         | 678k/8.77M [00:01<00:20, 409kB/s][00:00<00:01, 14.4MB/s]
#
# sub-control01_task-music_run-3_bold.nii.gz:  74%|███████▍  | 25.1M/33.9M [00:01<00:00, 28.2MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   1%|          | 253k/33.9M [00:01<03:14, 181kB/s]
#
#
#
# sub-control01_task-nonmusic_run-4_bold.nii.gz:  24%|██▍       | 8.28M/33.9M [00:00<00:01, 15.0MB/s]
# sub-control01_T1w.nii.gz:   8%|▊         | 746k/8.77M [00:01<00:18, 464kB/s]01<01:21, 429kB/s]
#
# sub-control01_task-music_run-3_bold.nii.gz:  82%|████████▏ | 27.9M/33.9M [00:01<00:00, 27.4MB/s]
#
#
#
# sub-control01_task-nonmusic_run-4_bold.nii.gz:  33%|███▎      | 11.2M/33.9M [00:01<00:01, 19.8MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   1%|          | 287k/33.9M [00:01<03:10, 185kB/s]
#
# sub-control01_task-music_run-3_bold.nii.gz:  91%|█████████ | 30.9M/33.9M [00:01<00:00, 28.4MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   2%|▏         | 746k/33.8M [00:01<01:18, 443kB/s]
#
#
#
# sub-control01_T1w.nii.gz:   9%|▉         | 813k/8.77M [00:02<00:19, 436kB/s][00:01<00:00, 22.8MB/s]
#
# sub-control01_task-music_run-3_bold.nii.gz: 100%|██████████| 33.9M/33.9M [00:01<00:00, 29.3MB/s]
#
#
#
#
#
# sub-control01_task-nonmusic_run-4_bold.nii.gz:  49%|████▉     | 16.7M/33.9M [00:01<00:00, 24.2MB/s]
#
#
# sub-control01_T1w.nii.gz:  10%|▉         | 882k/8.77M [00:02<00:19, 421kB/s]01<02:44, 214kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   2%|▏         | 848k/33.8M [00:02<01:12, 479kB/s]
#
#
#
# sub-control01_task-nonmusic_run-4_bold.nii.gz:  57%|█████▋    | 19.3M/33.9M [00:01<00:00, 24.4MB/s]
#
#
# sub-control01_T1w.nii.gz:  11%|█         | 966k/8.77M [00:02<00:16, 510kB/s]02<02:48, 208kB/s]
#
#
#
# sub-control01_task-nonmusic_run-4_bold.nii.gz:  65%|██████▌   | 22.2M/33.9M [00:01<00:00, 26.0MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   3%|▎         | 933k/33.8M [00:02<01:12, 478kB/s]
#
# sub-control01_task-nonmusic_run-4_events.tsv:   0%|          | 0.00/351 [00:00<?, ?B/s]
#
#
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   1%|          | 406k/33.9M [00:02<02:30, 233kB/s]
#
#
#
# sub-control01_T1w.nii.gz:  12%|█▏        | 1.01M/8.77M [00:02<00:17, 465kB/s]00:01<00:00, 27.5MB/s]
#
#
#
# sub-control01_task-nonmusic_run-4_bold.nii.gz:  83%|████████▎ | 28.2M/33.9M [00:01<00:00, 28.9MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   3%|▎         | 0.99M/33.8M [00:02<01:12, 476kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   1%|▏         | 457k/33.9M [00:02<02:17, 254kB/s]
#
#
#
# sub-control01_T1w.nii.gz:  12%|█▏        | 1.08M/8.77M [00:02<00:18, 441kB/s]00:01<00:00, 29.8MB/s]
#
#
#
#
# sub-control01_task-music_run-1_bold.nii.gz:   3%|▎         | 1.08M/33.8M [00:02<01:11, 481kB/s]
#
#
# sub-control01_T1w.nii.gz:  13%|█▎        | 1.16M/8.77M [00:02<00:15, 521kB/s]2<02:12, 264kB/s]
#
# sub-control01_task-nonmusic_run-5_bold.nii.gz:   0%|          | 0.00/33.9M [00:00<?, ?B/s]
# sub-control01_T1w.nii.gz:  14%|█▍        | 1.23M/8.77M [00:03<00:16, 485kB/s]02<01:05, 522kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   2%|▏         | 559k/33.9M [00:02<02:09, 270kB/s]
#
# sub-control01_task-nonmusic_run-5_bold.nii.gz:   0%|          | 83.6k/33.9M [00:00<01:14, 474kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   4%|▎         | 1.23M/33.8M [00:02<01:07, 509kB/s]
#
#
#
# sub-control01_task-nonmusic_run-5_events.tsv:   0%|          | 0.00/351 [00:00<?, ?B/s]
#
#
#
# sub-control01_T1w.nii.gz:  15%|█▍        | 1.29M/8.77M [00:03<00:14, 526kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   2%|▏         | 610k/33.9M [00:02<02:05, 277kB/s]
#
# sub-control01_task-nonmusic_run-5_bold.nii.gz:   1%|          | 203k/33.9M [00:00<00:59, 591kB/s]
# sub-control01_T1w.nii.gz:  15%|█▌        | 1.36M/8.77M [00:03<00:16, 485kB/s]03<01:04, 529kB/s]
#
# sub-control01_task-nonmusic_run-5_bold.nii.gz:   1%|▏         | 476k/33.9M [00:00<00:27, 1.29MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   2%|▏         | 678k/33.9M [00:03<01:53, 307kB/s]
# sub-control01_T1w.nii.gz:  16%|█▋        | 1.44M/8.77M [00:03<00:13, 562kB/s]03<00:57, 597kB/s]
#
# sub-control01_task-nonmusic_run-5_bold.nii.gz:   3%|▎         | 1.01M/33.9M [00:00<00:12, 2.67MB/s]
#
# sub-control01_task-nonmusic_run-5_bold.nii.gz:   5%|▌         | 1.84M/33.9M [00:00<00:07, 4.52MB/s]
# sub-control01_T1w.nii.gz:  17%|█▋        | 1.51M/8.77M [00:03<00:14, 512kB/s]03<01:03, 532kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   2%|▏         | 730k/33.9M [00:03<01:54, 303kB/s]
#
# sub-control01_task-nonmusic_run-5_bold.nii.gz:  11%|█         | 3.63M/33.9M [00:00<00:03, 8.85MB/s]
# sub-control01_T1w.nii.gz:  18%|█▊        | 1.59M/8.77M [00:03<00:12, 582kB/s]03<00:56, 603kB/s]
#
# sub-control01_task-nonmusic_run-5_bold.nii.gz:  18%|█▊        | 6.16M/33.9M [00:00<00:02, 14.2MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   2%|▏         | 797k/33.9M [00:03<01:46, 325kB/s]
# sub-control01_T1w.nii.gz:  19%|█▉        | 1.66M/8.77M [00:03<00:14, 526kB/s]03<01:03, 533kB/s]
#
# sub-control01_task-nonmusic_run-5_bold.nii.gz:  26%|██▌       | 8.88M/33.9M [00:01<00:01, 16.6MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   2%|▏         | 866k/33.9M [00:03<01:41, 343kB/s]
# sub-control01_T1w.nii.gz:  20%|█▉        | 1.74M/8.77M [00:03<00:12, 602kB/s]03<00:52, 642kB/s]
#
# sub-control01_task-nonmusic_run-5_bold.nii.gz:  34%|███▎      | 11.4M/33.9M [00:01<00:01, 18.5MB/s]
#
#
# sub-control01_T1w.nii.gz:  21%|██        | 1.81M/8.77M [00:04<00:11, 621kB/s]3<01:24, 407kB/s]
#
# sub-control01_task-nonmusic_run-5_bold.nii.gz:  39%|███▉      | 13.2M/33.9M [00:01<00:01, 17.6MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   5%|▌         | 1.81M/33.8M [00:03<00:56, 591kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   3%|▎         | 984k/33.9M [00:03<01:33, 371kB/s]
# sub-control01_T1w.nii.gz:  22%|██▏       | 1.89M/8.77M [00:04<00:12, 579kB/s]03<00:51, 653kB/s]
#
# sub-control01_task-nonmusic_run-5_bold.nii.gz:  46%|████▌     | 15.6M/33.9M [00:01<00:01, 18.2MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   3%|▎         | 1.03M/33.9M [00:03<01:18, 438kB/s]
#
# sub-control01_T1w.nii.gz:  22%|██▏       | 1.97M/8.77M [00:04<00:11, 641kB/s]00:01<00:00, 21.0MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   6%|▌         | 1.97M/33.8M [00:04<00:55, 600kB/s]
#
# sub-control01_task-nonmusic_run-5_bold.nii.gz:  61%|██████    | 20.7M/33.9M [00:01<00:00, 22.0MB/s]
#
#
# sub-control01_T1w.nii.gz:  23%|██▎       | 2.06M/8.77M [00:04<00:11, 594kB/s]04<01:28, 390kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   6%|▌         | 2.06M/33.8M [00:04<00:50, 654kB/s]
#
# sub-control01_T1w.nii.gz:  24%|██▍       | 2.14M/8.77M [00:04<00:10, 659kB/s]00:01<00:00, 23.8MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   3%|▎         | 1.14M/33.9M [00:04<01:15, 453kB/s]
#
# sub-control01_task-nonmusic_run-5_bold.nii.gz:  79%|███████▊  | 26.6M/33.9M [00:01<00:00, 26.7MB/s]
# sub-control01_T1w.nii.gz:  25%|██▌       | 2.22M/8.77M [00:04<00:09, 710kB/s]04<00:54, 605kB/s]
#
# sub-control01_task-nonmusic_run-5_bold.nii.gz:  86%|████████▋ | 29.2M/33.9M [00:01<00:00, 26.7MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   4%|▎         | 1.19M/33.9M [00:04<01:25, 402kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   7%|▋         | 2.24M/33.8M [00:04<00:47, 699kB/s]
#
# sub-control01_T1w.nii.gz:  26%|██▋       | 2.31M/8.77M [00:04<00:10, 631kB/s]00:02<00:00, 25.3MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   4%|▎         | 1.26M/33.9M [00:04<01:13, 466kB/s]
#
#
# sub-control01_T1w.nii.gz:  27%|██▋       | 2.40M/8.77M [00:04<00:09, 724kB/s]04<00:52, 632kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   7%|▋         | 2.42M/33.8M [00:04<00:45, 723kB/s]
#
#
# sub-control01_T1w.nii.gz:  28%|██▊       | 2.49M/8.77M [00:05<00:10, 644kB/s]04<01:17, 442kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   4%|▍         | 1.39M/33.9M [00:04<01:08, 496kB/s]
# sub-control01_T1w.nii.gz:  29%|██▉       | 2.59M/8.77M [00:05<00:08, 730kB/s]04<00:50, 646kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   8%|▊         | 2.62M/33.8M [00:05<00:42, 766kB/s]
#
#
# sub-control01_T1w.nii.gz:  30%|███       | 2.67M/8.77M [00:05<00:09, 658kB/s]04<01:13, 463kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   5%|▍         | 1.53M/33.9M [00:05<01:06, 513kB/s]
# sub-control01_T1w.nii.gz:  31%|███▏      | 2.75M/8.77M [00:05<00:08, 708kB/s]05<00:48, 679kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   8%|▊         | 2.81M/33.8M [00:05<00:42, 765kB/s]
#
#
# sub-control01_T1w.nii.gz:  33%|███▎      | 2.85M/8.77M [00:05<00:07, 784kB/s]05<01:11, 473kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   5%|▍         | 1.66M/33.9M [00:05<01:04, 526kB/s]
# sub-control01_T1w.nii.gz:  33%|███▎      | 2.94M/8.77M [00:05<00:08, 698kB/s]05<00:44, 732kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   9%|▉         | 2.99M/33.8M [00:05<00:43, 741kB/s]
#
#
# sub-control01_T1w.nii.gz:  34%|███▍      | 3.02M/8.77M [00:05<00:08, 737kB/s]05<01:05, 512kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   9%|▉         | 3.10M/33.8M [00:05<00:38, 848kB/s]
#
#
# sub-control01_T1w.nii.gz:  36%|███▌      | 3.12M/8.77M [00:06<00:07, 809kB/s]05<00:57, 588kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:   9%|▉         | 3.20M/33.8M [00:05<00:42, 760kB/s]
#
#
# sub-control01_T1w.nii.gz:  37%|███▋      | 3.22M/8.77M [00:06<00:07, 739kB/s]05<01:03, 524kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  10%|▉         | 3.32M/33.8M [00:05<00:37, 862kB/s]
#
#
# sub-control01_T1w.nii.gz:  39%|███▉      | 3.42M/8.77M [00:06<00:06, 863kB/s]05<00:55, 599kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  10%|█         | 3.42M/33.8M [00:06<00:41, 770kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   6%|▌         | 2.06M/33.9M [00:06<00:59, 563kB/s]
# sub-control01_T1w.nii.gz:  40%|████      | 3.52M/8.77M [00:06<00:07, 771kB/s]06<00:36, 874kB/s]
#
#
# sub-control01_T1w.nii.gz:  41%|████▏     | 3.63M/8.77M [00:06<00:06, 865kB/s]06<00:52, 630kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  11%|█         | 3.63M/33.8M [00:06<00:39, 812kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   7%|▋         | 2.22M/33.9M [00:06<00:56, 584kB/s]
# sub-control01_T1w.nii.gz:  43%|████▎     | 3.73M/8.77M [00:06<00:06, 782kB/s]06<00:39, 805kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   7%|▋         | 2.31M/33.9M [00:06<00:51, 646kB/s]
# sub-control01_T1w.nii.gz:  44%|████▎     | 3.83M/8.77M [00:06<00:06, 839kB/s]06<00:36, 867kB/s]
#
#
# sub-control01_T1w.nii.gz:  45%|████▌     | 3.95M/8.77M [00:07<00:05, 931kB/s]06<00:52, 630kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  12%|█▏        | 3.93M/33.8M [00:06<00:36, 854kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   7%|▋         | 2.49M/33.9M [00:06<00:47, 686kB/s]
# sub-control01_T1w.nii.gz:  46%|████▌     | 4.05M/8.77M [00:07<00:06, 820kB/s]06<00:36, 854kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  12%|█▏        | 4.15M/33.8M [00:06<00:33, 943kB/s]
#
#
# sub-control01_T1w.nii.gz:  47%|████▋     | 4.15M/8.77M [00:07<00:05, 876kB/s]06<00:47, 694kB/s]
#
#
# sub-control01_T1w.nii.gz:  49%|████▊     | 4.26M/8.77M [00:07<00:04, 959kB/s]06<00:42, 777kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  13%|█▎        | 4.25M/33.8M [00:07<00:35, 872kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:   8%|▊         | 2.82M/33.9M [00:07<00:36, 886kB/s]
# sub-control01_T1w.nii.gz:  50%|████▉     | 4.36M/8.77M [00:07<00:05, 897kB/s]07<00:33, 915kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  13%|█▎        | 4.45M/33.8M [00:07<00:33, 914kB/s]
#
#
# sub-control01_T1w.nii.gz:  51%|█████     | 4.46M/8.77M [00:07<00:05, 893kB/s]07<00:39, 819kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  13%|█▎        | 4.56M/33.8M [00:07<00:30, 992kB/s]
#
#
# sub-control01_T1w.nii.gz:  54%|█████▍    | 4.73M/8.77M [00:07<00:03, 1.12MB/s]7<00:35, 916kB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  14%|█▍        | 4.68M/33.8M [00:07<00:32, 947kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  10%|▉         | 3.22M/33.9M [00:07<00:33, 952kB/s]
# sub-control01_T1w.nii.gz:  55%|█████▌    | 4.85M/8.77M [00:07<00:03, 1.04MB/s]7<00:31, 968kB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  10%|▉         | 3.35M/33.9M [00:07<00:30, 1.05MB/s]
# sub-control01_T1w.nii.gz:  57%|█████▋    | 4.98M/8.77M [00:08<00:03, 1.07MB/s]7<00:28, 1.07MB/s]
#
#
# sub-control01_T1w.nii.gz:  58%|█████▊    | 5.13M/8.77M [00:08<00:03, 1.19MB/s]7<00:26, 1.18MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  15%|█▍        | 5.06M/33.8M [00:07<00:29, 1.04MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  11%|█         | 3.67M/33.9M [00:07<00:28, 1.12MB/s]
# sub-control01_T1w.nii.gz:  60%|██████    | 5.29M/8.77M [00:08<00:03, 1.20MB/s]8<00:27, 1.07MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  11%|█▏        | 3.83M/33.9M [00:07<00:24, 1.26MB/s]
# sub-control01_T1w.nii.gz:  62%|██████▏   | 5.44M/8.77M [00:08<00:02, 1.23MB/s]8<00:25, 1.20MB/s]
#
#
# sub-control01_T1w.nii.gz:  64%|██████▍   | 5.61M/8.77M [00:08<00:02, 1.36MB/s]8<00:21, 1.47MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  16%|█▋        | 5.51M/33.8M [00:08<00:25, 1.18MB/s]
#
#
# sub-control01_T1w.nii.gz:  66%|██████▌   | 5.77M/8.77M [00:08<00:02, 1.42MB/s]8<00:23, 1.31MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  17%|█▋        | 5.66M/33.8M [00:08<00:23, 1.23MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  13%|█▎        | 4.40M/33.9M [00:08<00:20, 1.50MB/s]
# sub-control01_T1w.nii.gz:  68%|██████▊   | 5.96M/8.77M [00:08<00:02, 1.44MB/s]8<00:22, 1.32MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  14%|█▎        | 4.63M/33.9M [00:08<00:17, 1.74MB/s]
# sub-control01_T1w.nii.gz:  70%|██████▉   | 6.14M/8.77M [00:08<00:01, 1.48MB/s]8<00:19, 1.52MB/s]
#
#
# sub-control01_T1w.nii.gz:  72%|███████▏  | 6.34M/8.77M [00:09<00:01, 1.64MB/s]8<00:20, 1.51MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  18%|█▊        | 6.16M/33.8M [00:08<00:21, 1.37MB/s]
#
#
# sub-control01_T1w.nii.gz:  75%|███████▍  | 6.54M/8.77M [00:09<00:01, 1.71MB/s]8<00:17, 1.78MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  19%|█▊        | 6.34M/33.8M [00:08<00:19, 1.46MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  16%|█▌        | 5.31M/33.9M [00:08<00:15, 1.99MB/s]
# sub-control01_T1w.nii.gz:  77%|███████▋  | 6.75M/8.77M [00:09<00:01, 1.73MB/s]8<00:18, 1.57MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  16%|█▋        | 5.53M/33.9M [00:08<00:16, 1.85MB/s]
# sub-control01_T1w.nii.gz:  79%|███████▉  | 6.97M/8.77M [00:09<00:01, 1.76MB/s]9<00:15, 1.81MB/s]
#
#
# sub-control01_T1w.nii.gz:  82%|████████▏ | 7.22M/8.77M [00:09<00:00, 1.97MB/s]9<00:15, 1.85MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  21%|██        | 6.94M/33.8M [00:09<00:17, 1.63MB/s]
#
#
# sub-control01_T1w.nii.gz:  85%|████████▍ | 7.44M/8.77M [00:09<00:00, 2.00MB/s]9<00:13, 2.10MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  21%|██        | 7.15M/33.8M [00:09<00:16, 1.74MB/s]
#
#
# sub-control01_T1w.nii.gz:  88%|████████▊ | 7.68M/8.77M [00:09<00:00, 2.16MB/s]9<00:12, 2.33MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  22%|██▏       | 7.37M/33.8M [00:09<00:14, 1.86MB/s]
#
#
# sub-control01_T1w.nii.gz:  90%|█████████ | 7.92M/8.77M [00:09<00:00, 2.14MB/s]9<00:11, 2.46MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  23%|██▎       | 7.64M/33.8M [00:09<00:13, 2.11MB/s]
#
#
# sub-control01_T1w.nii.gz:  93%|█████████▎| 8.17M/8.77M [00:09<00:00, 2.15MB/s]9<00:12, 2.27MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  23%|██▎       | 7.85M/33.8M [00:09<00:14, 1.92MB/s]
#
#
# sub-control01_T1w.nii.gz:  96%|█████████▌| 8.43M/8.77M [00:10<00:00, 2.31MB/s]9<00:11, 2.53MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  24%|██▍       | 8.10M/33.8M [00:09<00:13, 2.06MB/s]
#
#
#                                                                               9<00:09, 2.78MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  25%|██▍       | 8.33M/33.8M [00:09<00:12, 2.16MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  23%|██▎       | 7.80M/33.9M [00:09<00:09, 2.93MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  25%|██▌       | 8.58M/33.8M [00:10<00:11, 2.26MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  24%|██▍       | 8.15M/33.9M [00:09<00:09, 2.86MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  26%|██▋       | 8.90M/33.8M [00:10<00:10, 2.55MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  25%|██▍       | 8.45M/33.9M [00:10<00:09, 2.82MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  27%|██▋       | 9.16M/33.8M [00:10<00:10, 2.38MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  26%|██▌       | 8.80M/33.9M [00:10<00:08, 3.05MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  28%|██▊       | 9.46M/33.8M [00:10<00:09, 2.58MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  27%|██▋       | 9.21M/33.9M [00:10<00:07, 3.41MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  29%|██▊       | 9.73M/33.8M [00:10<00:09, 2.63MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  28%|██▊       | 9.63M/33.9M [00:10<00:06, 3.65MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  30%|██▉       | 10.0M/33.8M [00:10<00:09, 2.77MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  30%|██▉       | 10.0M/33.9M [00:10<00:07, 3.52MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  31%|███       | 10.3M/33.8M [00:10<00:08, 2.89MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  32%|███▏      | 10.7M/33.8M [00:10<00:07, 3.16MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  31%|███       | 10.4M/33.9M [00:10<00:07, 3.46MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  32%|███▏      | 10.8M/33.9M [00:10<00:06, 3.73MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  33%|███▎      | 11.1M/33.8M [00:10<00:07, 3.00MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  33%|███▎      | 11.3M/33.9M [00:10<00:05, 4.09MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  34%|███▎      | 11.4M/33.8M [00:10<00:07, 3.14MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  35%|███▍      | 11.8M/33.9M [00:10<00:05, 4.36MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  35%|███▍      | 11.8M/33.8M [00:11<00:06, 3.34MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  36%|███▋      | 12.3M/33.9M [00:11<00:04, 4.61MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  36%|███▌      | 12.1M/33.8M [00:11<00:06, 3.41MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  38%|███▊      | 12.7M/33.9M [00:11<00:05, 4.26MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  37%|███▋      | 12.6M/33.8M [00:11<00:06, 3.67MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  38%|███▊      | 13.0M/33.8M [00:11<00:05, 3.88MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  39%|███▉      | 13.2M/33.9M [00:11<00:05, 4.29MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  41%|████      | 13.7M/33.9M [00:11<00:04, 4.59MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  40%|███▉      | 13.4M/33.8M [00:11<00:05, 3.71MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  42%|████▏     | 14.3M/33.9M [00:11<00:04, 5.01MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  41%|████      | 13.8M/33.8M [00:11<00:05, 3.88MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  44%|████▍     | 14.9M/33.9M [00:11<00:03, 5.37MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  42%|████▏     | 14.2M/33.8M [00:11<00:04, 4.11MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  46%|████▌     | 15.5M/33.9M [00:11<00:03, 5.63MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  43%|████▎     | 14.7M/33.8M [00:11<00:04, 4.28MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  47%|████▋     | 16.1M/33.9M [00:11<00:03, 5.68MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  45%|████▍     | 15.1M/33.8M [00:11<00:04, 4.37MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  49%|████▉     | 16.6M/33.9M [00:11<00:03, 5.35MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  46%|████▌     | 15.6M/33.8M [00:12<00:04, 4.47MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  48%|████▊     | 16.1M/33.8M [00:12<00:03, 4.75MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  51%|█████     | 17.2M/33.9M [00:12<00:03, 5.40MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  49%|████▉     | 16.7M/33.8M [00:12<00:03, 5.08MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  53%|█████▎    | 17.8M/33.9M [00:12<00:02, 5.72MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  54%|█████▍    | 18.5M/33.9M [00:12<00:02, 5.95MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  51%|█████     | 17.2M/33.8M [00:12<00:03, 4.82MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  57%|█████▋    | 19.3M/33.9M [00:12<00:02, 6.66MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  52%|█████▏    | 17.7M/33.8M [00:12<00:03, 5.04MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  59%|█████▉    | 20.0M/33.9M [00:12<00:02, 6.86MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  54%|█████▍    | 18.3M/33.8M [00:12<00:03, 5.18MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  61%|██████    | 20.7M/33.9M [00:12<00:01, 7.19MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  56%|█████▌    | 18.9M/33.8M [00:12<00:02, 5.55MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  57%|█████▋    | 19.4M/33.8M [00:12<00:02, 5.64MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  63%|██████▎   | 21.4M/33.9M [00:12<00:01, 6.84MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  59%|█████▉    | 20.1M/33.8M [00:12<00:02, 5.91MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  65%|██████▌   | 22.1M/33.9M [00:12<00:01, 6.70MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  61%|██████    | 20.7M/33.8M [00:12<00:02, 6.14MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  68%|██████▊   | 23.0M/33.9M [00:12<00:01, 7.18MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  63%|██████▎   | 21.3M/33.8M [00:13<00:02, 6.12MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  70%|███████   | 23.8M/33.9M [00:12<00:01, 7.74MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  65%|██████▍   | 22.0M/33.8M [00:13<00:01, 6.23MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  73%|███████▎  | 24.7M/33.9M [00:13<00:01, 8.15MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  67%|██████▋   | 22.6M/33.8M [00:13<00:01, 6.38MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  75%|███████▌  | 25.6M/33.9M [00:13<00:01, 8.34MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  69%|██████▉   | 23.3M/33.8M [00:13<00:01, 6.60MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  78%|███████▊  | 26.5M/33.9M [00:13<00:00, 8.67MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  71%|███████▏  | 24.2M/33.8M [00:13<00:01, 7.13MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  81%|████████  | 27.3M/33.9M [00:13<00:00, 8.42MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  74%|███████▎  | 24.9M/33.8M [00:13<00:01, 7.14MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  83%|████████▎ | 28.2M/33.9M [00:13<00:00, 8.59MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  76%|███████▌  | 25.6M/33.8M [00:13<00:01, 7.19MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  86%|████████▌ | 29.0M/33.9M [00:13<00:00, 8.44MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  78%|███████▊  | 26.5M/33.8M [00:13<00:00, 7.77MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  89%|████████▉ | 30.1M/33.9M [00:13<00:00, 9.11MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  80%|████████  | 27.2M/33.8M [00:13<00:00, 7.89MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  92%|█████████▏| 31.1M/33.9M [00:13<00:00, 9.55MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  83%|████████▎ | 28.0M/33.8M [00:13<00:00, 8.06MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  95%|█████████▍| 32.1M/33.9M [00:13<00:00, 9.87MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  85%|████████▌ | 28.8M/33.8M [00:14<00:00, 7.96MB/s]
#
#
# sub-control01_task-music_run-2_bold.nii.gz:  98%|█████████▊| 33.2M/33.9M [00:14<00:00, 10.4MB/s]
#
#
#
# sub-control01_task-music_run-1_bold.nii.gz:  88%|████████▊ | 29.7M/33.8M [00:14<00:00, 8.14MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  90%|█████████ | 30.5M/33.8M [00:14<00:00, 8.28MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  93%|█████████▎| 31.4M/33.8M [00:14<00:00, 8.62MB/s]
# sub-control01_task-music_run-1_bold.nii.gz:  96%|█████████▌| 32.4M/33.8M [00:14<00:00, 9.17MB/s]
# ✅ Finished downloading ds000171.
#
# 🧠 Please enjoy your brains.
# sub-control01_task-music_run-1_bold.nii.gz:  99%|█████████▊| 33.4M/33.8M [00:14<00:00, 9.45MB/s]
# CompletedProcess(args=['openneuro-py', 'download', '--dataset', 'ds000171', '--target-dir', '/home/jovyan/Mini_Project_1/dataset/ds000171', '--include', 'sub-control01'], returncode=0)

# %%
print_dir_tree(bids_root, max_depth=5)
# Out:
# |ds000171/
# |--- CHANGES
# |--- README
# |--- dataset_description.json
# |--- participants.tsv
# |--- sub-control01/
# |------ anat/
# |--------- sub-control01_T1w.nii.gz
# |------ func/
# |--------- sub-control01_task-music_run-1_bold.nii.gz
# |--------- sub-control01_task-music_run-1_events.tsv
# |--------- sub-control01_task-music_run-2_bold.nii.gz
# |--------- sub-control01_task-music_run-2_events.tsv
# |--------- sub-control01_task-music_run-3_bold.nii.gz
# |--------- sub-control01_task-music_run-3_events.tsv
# |--------- sub-control01_task-nonmusic_run-4_bold.nii.gz
# |--------- sub-control01_task-nonmusic_run-4_events.tsv
# |--------- sub-control01_task-nonmusic_run-5_bold.nii.gz
# |--------- sub-control01_task-nonmusic_run-5_events.tsv

# %%
import os
import numpy as np
import nibabel as nib
import glob
import os.path as op
import subprocess
from nilearn.image import smooth_img
from nilearn.image import new_img_like

# Define paths
dataset_id = 'ds000171'
subject = 'control01'
sample_path = "/home/jovyan/Mini_Project_1/dataset"
bids_root = op.join(os.path.abspath(""), sample_path, dataset_id)
subject_dir = f'sub-{subject}'
func_dir = op.join(bids_root, subject_dir, 'func')

# Find all music-related functional runs
music_runs = sorted(glob.glob(op.join(func_dir, f'{subject_dir}_task-music_run-*_bold.nii.gz')))

if len(music_runs) == 0:
    raise FileNotFoundError("No music runs found!")

# Helper function to standardize each run (z-scoring)
def standardize_data(data):
    mean_data = np.mean(data, axis=-1, keepdims=True)
    std_data = np.std(data, axis=-1, keepdims=True)
    std_data[std_data == 0] = 1  # Avoid division by zero
    standardized_data = (data - mean_data) / std_data
    return standardized_data

# Initialize a list to store paths of preprocessed runs
preprocessed_runs = []

# Preprocessing for each run
for run in music_runs:
    # Load the run data using nibabel
    img = nib.load(run)
    data = img.get_fdata()

    # Step 1: Motion Correction
    mc_run_path = run.replace('.nii.gz', '_mc.nii.gz')
    subprocess.run(['mcflirt', '-in', run, '-out', mc_run_path, '-refvol', '0', '-plots'], check=True)

    # Step 2: Smoothing
    smoothed_img_path = mc_run_path.replace('.nii.gz', '_smoothed.nii.gz')
    smoothed_img = smooth_img(mc_run_path, fwhm=6)  # 6mm smoothing
    nib.save(smoothed_img, smoothed_img_path)

    # Load smoothed data
    smoothed_data = smoothed_img.get_fdata()

    # Step 3: Standardize the smoothed data (z-scoring)
    standardized_data = standardize_data(smoothed_data)

    # Save the standardized data as a new NIfTI file
    standardized_img = new_img_like(smoothed_img, standardized_data)
    standardized_img_path = smoothed_img_path.replace('.nii.gz', '_standardized.nii.gz')
    nib.save(standardized_img, standardized_img_path)

    # Append the path of the standardized run
    preprocessed_runs.append(standardized_img_path)

# Step 4: Concatenate the standardized runs
all_runs_data = []
for run in preprocessed_runs:
    img = nib.load(run)
    all_runs_data.append(img.get_fdata())

# Concatenate along the time dimension
concatenated_data = np.concatenate(all_runs_data, axis=-1)

# Save the concatenated data into a new NIfTI file
new_img = nib.Nifti1Image(concatenated_data, img.affine)
output_file = op.join(func_dir, f'{subject_dir}_task-music_allruns_bold_concat_preprocessed.nii.gz')
nib.save(new_img, output_file)

print(f"Preprocessed and concatenated runs saved as {output_file}")
# Out:
# Preprocessed and concatenated runs saved as /home/jovyan/Mini_Project_1/dataset/ds000171/sub-control01/func/sub-control01_task-music_allruns_bold_concat_preprocessed.nii.gz

# %%
import matplotlib.pyplot as plt

def plot_slices(img, title):
    data = img.get_fdata()
    
    # Check the shape of the data
    print(f"Data shape: {data.shape}")

    # Ensure data is 3D
    if data.ndim != 3:
        raise ValueError("Expected 3D data for plotting slices.")

    # Get the middle index for the z dimension
    middle_index = data.shape[2] // 2

    # Plotting the middle slice from the z-dimension
    fig, axes = plt.subplots(1, 3, figsize=(15, 5))

    # Choose three slices around the middle slice for visualization
    slice_indices = [middle_index - 1, middle_index, middle_index + 1]
    
    for i, axis in enumerate(axes):
        # Ensure the index is within bounds
        if 0 <= slice_indices[i] < data.shape[2]:
            axis.imshow(data[:, :, slice_indices[i]], cmap='gray', aspect='auto')
            axis.set_title(f'Slice {slice_indices[i]}')
        else:
            # If out of bounds, show a blank image
            axis.imshow(np.zeros(data.shape[0:2]), cmap='gray', aspect='auto')  # Empty slice
            axis.set_title('Out of bounds')
        axis.axis('off')
    
    plt.suptitle(title)
    plt.show()

# %%
# Visualize the original run
original_img = nib.load(run)
plot_slices(original_img, title='Original Run')

# Visualize the motion-corrected image
mc_img = nib.load(mc_run_path)
plot_slices(mc_img, title='Motion-Corrected Image')

# Visualize the smoothed image
smoothed_img = nib.load(smoothed_img_path)
plot_slices(smoothed_img, title='Smoothed Image')

# Visualize the standardized image
standardized_img = nib.load(standardized_img_path)
plot_slices(standardized_img, title='Standardized Image')

# Visualize the concatenated output
concatenated_img = nib.Nifti1Image(concatenated_data, img.affine)
plot_slices(concatenated_img, title='Concatenated Image')
# Out:
# Data shape: (80, 80, 50, 105)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 3
#       1 # Visualize the original run
#       2 original_img = nib.load(run)
# ----> 3 plot_slices(original_img, title='Original Run')
#       5 # Visualize the motion-corrected image
#       6 mc_img = nib.load(mc_run_path)
#
# Cell In[16], line 11, in plot_slices(img, title)
#       9 # Ensure data is 3D
#      10 if data.ndim != 3:
# ---> 11     raise ValueError("Expected 3D data for plotting slices.")
#      13 # Get the middle index for the z dimension
#      14 middle_index = data.shape[2] // 2
#
# ValueError: Expected 3D data for plotting slices.
